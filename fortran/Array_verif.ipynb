# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat'
file_path2 = 'planck_2018_lensedCls_Dark.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()
with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

l = []
maxl = 2600

for i in range(maxl-2):
    l.append(float(liste1[i*5]))

Dltt1 = []
Dltt2 = []

del liste1[0]
##
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*5]))

for i in range(maxl-2):
    Dltt2.append(float(liste2[i*5]))

#l = np.arange(2,maxl)

#print(len(l))

#relativ_error = []

#for i in range(maxl-2):
#    relativ_error.append((Dltt1[i]-Dltt2[i])/Dltt2[i])

#print(len(relativ_error))
#plt.plot(l,relativ_error)
#plt.ylabel('CLT fractional difference at f = 353 Hz')
#plt.xlabel('echelle angulaire (l)')
#plt.savefig("fraction_diff_6_6.png")
#plt.xscale('log')
#plt.xlim([0,2600])
#plt.ylim([-0.05,0.05])
#plt.grid()
#plt.savefig("fraction_diff_4_4.png")
#plt.plot(l,Dltt2)
#plt.plot(l,Dltt2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 19
#      16 maxl = 2600
#      18 for i in range(maxl-2):
# ---> 19     l.append(float(liste1[i*5]))
#      21 Dltt1 = []
#      22 Dltt2 = []
#
# ValueError: could not convert string to float: '#'

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat_6_6'
file_path2 = 'planck_2018_lensedCls.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()
with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

l = []
maxl = 2600

for i in range(maxl-2):
    l.append(float(liste1[i*5]))

Dltt1 = []
Dltt2 = []

del liste1[0]
##
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*5]))

for i in range(maxl-2):
    Dltt2.append(float(liste2[i*5]))

l = np.arange(2,maxl)

print(len(l))

relativ_error = []

for i in range(maxl-2):
    relativ_error.append((Dltt1[i]-Dltt2[i])/Dltt2[i])

print(len(relativ_error))
#plt.plot(l,relativ_error)
plt.ylabel('CLT fractional difference at f = 353 Hz')
plt.xlabel('echelle angulaire (l)')
plt.savefig("fraction_diff_6_6.png")
#plt.xscale('log')
#plt.ylim([-0.3,0.1])
#plt.savefig("fraction_diff_4_4.png")
#plt.plot(l,Dltt1)
plt.plot(l,Dltt2)
# Out:
# 2598
# 2598

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat_6_6'
file_path2 = 'planck_2018_lensedCls.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()
with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

l = []
maxl = 2600

for i in range(maxl-2):
    l.append(float(liste1[i*5]))

Dltt1 = []
Dltt2 = []

del liste1[0]
##
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*5]))

for i in range(maxl-2):
    Dltt2.append(float(liste2[i*5]))

l = np.arange(2,maxl)

print(len(l))

relativ_error = []

#for i in range(maxl-2):
#    relativ_error.append((Dltt1[i]-Dltt2[i])/Dltt2[i])

print(len(relativ_error))
#plt.plot(l,relativ_error)
plt.ylabel('CLT fractional difference at f = 353 Hz')
plt.xlabel('echelle angulaire (l)')
plt.savefig("fraction_diff_6_6.png")
#plt.xscale('log')
#plt.ylim([-0.3,0.1])
#plt.savefig("fraction_diff_4_4.png")
#plt.plot(l,Dltt1)
plt.plot(l,Dltt2)
# Out:
# 2598
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat_6_6'
file_path2 = 'planck_2018_lensedCls.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()
with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

l = []
maxl = 2600

for i in range(maxl-2):
    l.append(float(liste1[i*5]))

Dltt1 = []
Dltt2 = []

del liste1[0]
##
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*5]))

for i in range(maxl-2):
    Dltt2.append(float(liste2[i*5]))

l = np.arange(2,maxl)

print(len(l))

relativ_error = []

#for i in range(maxl-2):
#    relativ_error.append((Dltt1[i]-Dltt2[i])/Dltt2[i])

print(len(relativ_error))
#plt.plot(l,relativ_error)
plt.ylabel('CLT fractional difference at f = 353 Hz')
plt.xlabel('echelle angulaire (l)')
plt.savefig("fraction_diff_6_6.png")
#plt.xscale('log')
plt.ylim([0,8000])
#plt.savefig("fraction_diff_4_4.png")
#plt.plot(l,Dltt1)
plt.plot(l,Dltt2)
# Out:
# 2598
# 0
