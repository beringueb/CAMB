# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'array.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()

liste1 = list(content1.split())

#print(liste1[0:10])

l = []


for i in range(40000):
    l.append(float(liste1[i*8]))

Dltt1 = []

del liste1[0]
#del liste1[0]

for i in range(40000):
    Dltt1.append(float(liste1[i*8]))


print(Dltt1[0:10])
print(len(l))
print(len(Dltt1))

#print(Dltt1[10])
#print(Dltt1[100])
#print(Dltt1[1000])
plt.plot(l,Dltt1)
#plt.ylabel('arr vals')
#plt.xlabel('x val')
#plt.yscale('log')
#plt.ylim((0,6000))
#plt.ylim((0,10))
plt.savefig("SDOTMU_ORIGIN.png")
# Out:
# [2971070751048.8984, 2968379249558.1733, 2965690186310.477, 2963003559100.6904, 2960319365725.668, 2957637603982.5605, 2954958271666.6694, 2952281366574.775, 2949606886505.6597, 2946934829260.1045]
# 40000
# 40000
