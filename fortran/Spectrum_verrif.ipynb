# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat_1_1'
file_path2 = 'planck_2018_lensedCls.dat_2_2'

with open(file_path1, 'r') as file:
    content1 = file.read()
with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

l = []
maxl = 2600

del liste1[0]

for i in range(maxl-2):
    l.append(float(liste1[i*5]))

Dltt1 = []
Dltt2 = []

##
del liste2[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*5]))

for i in range(maxl-2):
    Dltt2.append(float(liste2[i*5]))

l = np.arange(2,maxl)

##print(len(l))

relativ_error = []

for i in range(maxl-2):
    relativ_error.append((Dltt2[i]-Dltt1[i])/Dltt1[i])

#print(relativ_error[0:10])
#plt.plot(l,relativ_error,'midnightblue')
plt.ylabel('Dltt (µK²)')
plt.xlabel('Echelle angulaire (l)')
#plt.savefig("fraction_diff_5_5.png")
#plt.xscale('log')
#plt.ylim([-0.3,0.1])
plt.plot(l,Dltt2,'midnightblue')
#plt.plot(l,Dltt2, linestyle='--', color='crimson')
plt.legend(['ν = 800 GHz'], loc='upper right')
#plt.savefig("800diffV2.png")

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat_1_1'
file_path2 = 'planck_2018_lensedCls.dat_4_4'

with open(file_path1, 'r') as file:
    content1 = file.read()
with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

l = []
maxl = 2500

del liste1[0]

for i in range(maxl-2):
    l.append(float(liste1[i*5]))

Dltt1 = []
Dltt2 = []

##
del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*5]))

for i in range(maxl-2):
    Dltt2.append(float(liste2[i*5]))

l = np.arange(2,maxl)

##print(len(l))

relativ_error = []

#for i in range(maxl-2):
#    relativ_error.append((Dltt2[i]-Dltt1[i])/Dltt2[i])

#print(len(relativ_error))
#plt.plot(l,relativ_error)
plt.ylabel('Dltt (µK²)')
plt.xlabel('echelle angulaire (l)')
#plt.savefig("fraction_diff_2_2.png")
#plt.xscale('log')
#plt.ylim([-0.3,0.1])
#plt.savefig("fraction_diff_4_4.png")
plt.plot(l,Dltt1)
plt.plot(l,Dltt2)

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat_6_1'
file_path2 = 'planck_2018_lensedCls.dat_4_1'

with open(file_path1, 'r') as file:
    content1 = file.read()
with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

l = []
maxl = 2500

del liste1[0]

for i in range(maxl-2):
    l.append(float(liste1[i*5]))

Dltt1 = []
Dltt2 = []

##
del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]
#del liste2[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*5]))

for i in range(maxl-2):
    Dltt2.append(float(liste2[i*5]))

l = np.arange(2,maxl)

##print(len(l))

line = []
relativ_error = []
relativ_error2 = []

for i in range(maxl-2):
    relativ_error.append((Dltt2[i]-Dltt1[i])/Dltt1[i])
    relativ_error2.append(Dltt2[i]/Dltt1[i])
    line.append(0.0625)

#plt.plot(l,relativ_error,'b')
plt.plot(l,relativ_error2,'k')
plt.plot(l,line,'r')
plt.ylabel('CLT fractional difference at f = 353 Hz')
plt.xlabel('echelle angulaire (l)')
plt.savefig("fraction_diff_6_6.png")
plt.ylim([0.06,0.065])
#plt.xscale('log')
#plt.ylim([-0.3,0.1])
#plt.savefig("fraction_diff_4_4.png")
#plt.plot(l,Dltt1)
#plt.plot(l,Dltt2)
# Out:
# (0.06, 0.065)
