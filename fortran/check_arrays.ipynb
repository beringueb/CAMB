# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'check_array.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()

liste1 = list(content1.split())

l = []
maxl = 600

Dltt1 = []

del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*15]))

l = np.arange(2,maxl)

plt.plot(l,Dltt1)
plt.ylabel('CLT fractional difference at f = 353 Hz')
plt.xlabel('echelle angulaire (l)')

print(Dltt1[27])
# Out:
# -0.00792814829843348

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'cls_array.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()

liste1 = list(content1.split())

l = []
maxl = 90

Dltt1 = []

del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]

for i in range(maxl-2):
    Dltt1.append(float(liste1[i*15]))

l = np.arange(2,maxl)

plt.plot(l,Dltt1)
plt.ylabel('CLT fractional difference at f = 353 Hz')
plt.xlabel('echelle angulaire (l)')

print(Dltt1[27])
# Out:
# 0.0
