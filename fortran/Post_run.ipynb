# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import sys, platform, os
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import camb
from camb import model, initialpower
print('Using CAMB %s installed at %s'%(camb.__version__,os.path.dirname(camb.__file__)))
# make sure the version and path is what you expect
# Out:
# Using CAMB 1.5.5 installed at /home/andrea/.local/lib/python3.10/site-packages/camb

# %%
file_path1 = 'planck_2018_scalCls.dat'
file_path2 = 'test_rayleigh_scalCls.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()

with open(file_path2, 'r') as file:
    content2 = file.read()

liste1 = list(content1.split())
liste2 = list(content2.split())

for i in range(8):
    del liste1[0]
    del liste2[0]
    
run_Dltt1 = []
run_Dltt2 = []
Relativ_diff = []

for i in range(int((len(liste1)+1)/6)):
    run_Dltt1.append(float(liste1[i*6]))
    run_Dltt2.append(float(liste2[i*6]))
    Relativ_diff.append(((run_Dltt1[i]-run_Dltt2[i])/run_Dltt2[i])*100)
    
l = np.arange(2,2701)

print(np.mean(Relativ_diff))

plt.plot(l,Relativ_diff)
plt.ylabel('Différence relative (%)')
plt.xlabel('echelle angulaire (l)')
#plt.ylim((0,100000))
plt.savefig('relative_diff')
#print(run_Dltt1)
# Out:
# -99.99972996043209
