# %%
import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_lensedCls.dat_6_6'
t^_hkkjgb
with open(file_path1, 'r') as file:
    content1 = file.read()

liste1 = list(content1.split())


del liste1[0]

Dltt1 = []


for i in range(int((len(liste1)+1)/5)):
    Dltt1.append(float(liste1[i*5]))

l = np.arange(2,len(Dltt1)+2)

print(Dltt1[0])
print(Dltt1[10])
print(Dltt1[100])
print(Dltt1[1000])
plt.plot(l,Dltt1)
plt.ylabel('CTT_6_6')
plt.xlabel('echelle angulaire (l)')
#plt.yscale('log')
#plt.ylim((0,8000))
plt.savefig("CTT_6_6.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 file_path1 = 'planck_2018_lensedCls.dat_6_6'
# ----> 5 t^_hkkjgb
#       6 with open(file_path1, 'r') as file:
#       7     content1 = file.read()
#
# NameError: name 't' is not defined

# %%
liste1 = list(content1.split())

Dltt1 = []

del liste1[0]
del liste1[0]

for i in range(int((len(liste1))/5)):
    Dltt1.append(float(liste1[i*5]))

l = np.arange(2,len(Dltt1)+2)

print(Dltt1[0])
print(Dltt1[10])
print(Dltt1[100])
print(Dltt1[1000])
print(Dltt1[2500])
plt.plot(l,Dltt1)
plt.ylabel('CEE (%)')
plt.xlabel('echelle angulaire (l)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 liste1 = list(content1.split())
#       3 Dltt1 = []
#       5 del liste1[0]
#
# NameError: name 'content1' is not defined

# %%
liste1 = list(content1.split())

Dltt1 = []

del liste1[0]
del liste1[0]
del liste1[0]

for i in range(int((len(liste1))/5)):
    Dltt1.append(float(liste1[i*5]))

l = np.arange(2,len(Dltt1)+2)

print(Dltt1[0])
print(Dltt1[10])
print(Dltt1[100])
print(Dltt1[1000])
plt.plot(l,Dltt1)
plt.ylabel('CBB (%)')
plt.xlabel('echelle angulaire (l)')
# Out:
# 0.000358391
# 0.00887066
# 0.531958
# 59.9462
# Text(0.5, 0, 'echelle angulaire (l)')

# %%
liste1 = list(content1.split())

Dltt1 = []

del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]

for i in range(int((len(liste1))/5)):
    Dltt1.append(float(liste1[i*5]))

l = np.arange(2,len(Dltt1)+2)

print(Dltt1[0])
print(Dltt1[10])
print(Dltt1[100])
print(Dltt1[1000])
plt.plot(l,Dltt1)
plt.ylabel('CBE (%)')
plt.xlabel('echelle angulaire (l)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8 del liste1[0]
#      10 for i in range(int((len(liste1))/5)):
# ---> 11     Dltt1.append(float(liste1[i*5]))
#      13 l = np.arange(2,len(Dltt1)+2)
#      15 print(Dltt1[0])
#
# ValueError: could not convert string to float: 'TE'

# %%
# Cls sans rayleigh, ie freq nu = 0 :

import numpy as np
import matplotlib.pyplot as plt

file_path1 = 'planck_2018_scalCls.dat'

with open(file_path1, 'r') as file:
    content1 = file.read()

liste1 = list(content1.split())


del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]
del liste1[0]

Dltt1 = []


for i in range(int((len(liste1)+1)/6)):
    Dltt1.append(float(liste1[i*6]))

l = np.arange(2,len(Dltt1)+2)

#print(Dltt1)

print(Dltt1[0])
print(Dltt1[1])
#pprint(Dltt1[2])
#pprint(Dltt1[3])
#pprint(Dltt1[4])
#pprint(Dltt1[5])
plt.plot(l,Dltt1)
plt.ylabel('CTT Thomson')
plt.xlabel('echelle angulaire (l)')
plt.savefig("CTT Thomson.png")
# Out:
# 1246.41
# 1197.4
